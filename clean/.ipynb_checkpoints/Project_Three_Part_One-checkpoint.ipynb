# %% [markdown]
# # Project Three, Part One:

# %%
# %pip install praw --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pytrends --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import altair as alt
import praw
import pytrends

print("libraries ready")
# Out:
# libraries ready

# %%
from dotenv import load_dotenv
import os

load_dotenv()
API_KEY = os.getenv("GOOGLE_BOOKS_API_KEY")

# %%
#review google book api 
def search_google_books(title, author):
    query = f"intitle:{title} inauthor:{author}"
    url = "https://www.googleapis.com/books/v1/volumes"
    params = {"q": query,}
    response = requests.get(url, params=params)
    return response.json()

result = search_google_books("Legends & Lattes", "Travis Baldree")
result
# Out:
# {'error': {'code': 429,
#   'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'books.googleapis.com' for consumer 'project_number:624717413613'.",
#   'errors': [{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'books.googleapis.com' for consumer 'project_number:624717413613'.",
#     'domain': 'global',
#     'reason': 'rateLimitExceeded'}],
#   'status': 'RESOURCE_EXHAUSTED',
#   'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo',
#     'reason': 'RATE_LIMIT_EXCEEDED',
#     'domain': 'googleapis.com',
#     'metadata': {'quota_unit': '1/d/{project}',
#      'service': 'books.googleapis.com',
#      'quota_limit': 'defaultPerDayPerProject',
#      'quota_location': 'global',
#      'quota_limit_value': '0',
#      'consumer': 'projects/624717413613',
#      'quota_metric': 'books.googleapis.com/default'}},
#    {'@type': 'type.googleapis.com/google.rpc.Help',
#     'links': [{'description': 'Request a higher quota limit.',
#       'url': 'https://cloud.google.com/docs/quotas/help/request_increase'}]}]}}
